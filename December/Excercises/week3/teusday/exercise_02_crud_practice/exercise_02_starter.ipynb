# %%
"""
Exercise 02: CRUD Practice - Starter Code

Complete the TODOs to practice all CRUD operations in Chroma DB.

Prerequisites:
- pip install chromadb

Hints:
- Reading 04 (crud-operations-vector-data.md) has method signatures
- Demo 02 (demo_02_crud_operations.py) shows each operation
"""

import chromadb

# ============================================================================
# SETUP
# ============================================================================

print("=" * 60)
print("Exercise 02: CRUD Practice")
print("=" * 60)

# Create an in-memory client for practice
client = chromadb.Client()

# Create a collection for our knowledge base
# Hint: client.create_collection() or client.get_or_create_collection()
collection = client.get_or_create_collection("knowledge_base")
# Out:
# ============================================================
# Exercise 02: CRUD Practice
# ============================================================

# %%
# ============================================================================
# PART 1: CREATE Operations
# ============================================================================

print("\n" + "=" * 60)
print("Part 1: CREATE Operations")
print("=" * 60)

# TODO 1.1: Add these 5 documents with metadata
# Hint: collection.add(documents=[...], ids=[...], metadatas=[...])

documents = [
    "Python is a versatile programming language used for web development, data science, and automation.",
    "Machine learning models require large datasets for training and validation.",
    "Docker containers provide consistent environments across development and production.",
    "Neural networks are inspired by the structure of biological brains.",
    "REST APIs use HTTP methods like GET, POST, PUT, and DELETE."
]

ids = ["doc_python", "doc_ml", "doc_docker", "doc_neural", "doc_api"]

metadatas = [
    {"category": "programming", "author": "alice", "difficulty": "beginner"},
    {"category": "ai", "author": "bob", "difficulty": "intermediate"},
    {"category": "devops", "author": "alice", "difficulty": "intermediate"},
    {"category": "ai", "author": "carol", "difficulty": "advanced"},
    {"category": "programming", "author": "bob", "difficulty": "beginner"}
]

# Your add() call here:
for i in range(len(documents)):
    collection.add(documents=[documents[i]], ids=[ids[i]], metadatas=[metadatas[i]])

print(f"Added documents. Collection count: {collection.count()}")


# TODO 1.2: Try adding a duplicate ID and observe the error
# Hint: Wrap in try/except to see the error message
print("\n[Task 1.2] Testing duplicate ID handling...")
# Your code here:
try:
    existing_ids = collection.get(ids=["doc_python"])["ids"]
    if "doc_python" in existing_ids:
        print(f"\n[ERROR] Duplicate ID detected: 'doc_python' already exists")
        print(f"ChromaDB's add() method will UPDATE existing documents instead of raising an error")
    else:
        collection.add(documents=["Duplicate document"], ids=["doc_python"])
except Exception as e:
    print(f"\n[ERROR] Exception occurred: {e}")
# Out:
# ============================================================
# Part 1: CREATE Operations
# ============================================================
# Added documents. Collection count: 5
#
# [Task 1.2] Testing duplicate ID handling...
#
# [ERROR] Duplicate ID detected: 'doc_python' already exists
# ChromaDB's add() method will UPDATE existing documents instead of raising an error

# %% [markdown]
# ### NOTE:
# ChromaDB add() function automatically switched to updating the field if the id already exists.

# %%
# ============================================================================
# PART 2: READ Operations
# ============================================================================

print("\n" + "=" * 60)
print("Part 2: READ Operations")
print("=" * 60)

# TODO 2.1: Get document by ID
# Hint: collection.get(ids=["doc_python"])
print("\n[Task 2.1] Get by ID 'doc_python':")
result = collection.get(ids=["doc_python"])
print(result)


# TODO 2.2a: Get documents where category = "ai"
# Hint: collection.get(where={"category": "ai"})
print("\n[Task 2.2a] Get documents in 'ai' category:")
# Your code here:
result = collection.get(where={"category": "ai"})
print(result)


# TODO 2.2b: Get documents where author = "alice"
print("\n[Task 2.2b] Get documents by author 'alice':")
# Your code here:
result = collection.get(where={"author": "alice"})
print(result)


# TODO 2.3: Similarity query
# Hint: collection.query(query_texts=[...], n_results=3)
print("\n[Task 2.3] Query: 'How do I build an AI model?'")
results = collection.query(query_texts=["How do I build an AI model?"], n_results=3)
for doc, dist in zip(results['documents'][0], results['distances'][0]):
    print(f"  [{dist:.4f}] {doc[:50]}...")


# TODO 2.4: Query with filter
# Hint: Combine query_texts with where parameter
print("\n[Task 2.4] Query programming docs for 'build a web service':")
# Your code here:
results = collection.query(
    query_texts=["build a web service"], 
    where={"category": "programming"}
)
for doc, dist in zip(results['documents'][0], results['distances'][0]):
    print(f"  [{dist:.4f}] {doc[:50]}...")
# Out:
# ============================================================
# Part 2: READ Operations
# ============================================================
#
# [Task 2.1] Get by ID 'doc_python':
# {'ids': ['doc_python'], 'embeddings': None, 'documents': ['Python is a versatile programming language used for web development, data science, and automation.'], 'uris': None, 'included': ['metadatas', 'documents'], 'data': None, 'metadatas': [{'author': 'alice', 'category': 'programming', 'difficulty': 'beginner'}]}
#
# [Task 2.2a] Get documents in 'ai' category:
# {'ids': ['doc_ml', 'doc_neural'], 'embeddings': None, 'documents': ['Machine learning models require large datasets for training and validation.', 'Neural networks are inspired by the structure of biological brains.'], 'uris': None, 'included': ['metadatas', 'documents'], 'data': None, 'metadatas': [{'difficulty': 'intermediate', 'author': 'bob', 'category': 'ai'}, {'category': 'ai', 'difficulty': 'advanced', 'author': 'carol'}]}
#
# [Task 2.2b] Get documents by author 'alice':
# {'ids': ['doc_python', 'doc_docker'], 'embeddings': None, 'documents': ['Python is a versatile programming language used for web development, data science, and automation.', 'Docker containers provide consistent environments across development and production.'], 'uris': None, 'included': ['metadatas', 'documents'], 'data': None, 'metadatas': [{'author': 'alice', 'difficulty': 'beginner', 'category': 'programming'}, {'difficulty': 'intermediate', 'author': 'alice', 'category': 'devops'}]}
#
# [Task 2.3] Query: 'How do I build an AI model?'
#   [1.3256] Neural networks are inspired by the structure of b...
#   [1.4314] Machine learning models require large datasets for...
#   [1.7518] Python is a versatile programming language used fo...
#
# [Task 2.4] Query programming docs for 'build a web service':
#   [1.5258] REST APIs use HTTP methods like GET, POST, PUT, an...
#   [1.6169] Python is a versatile programming language used fo...

# %%
# ============================================================================
# PART 3: UPDATE Operations
# ============================================================================

print("\n" + "=" * 60)
print("Part 3: UPDATE Operations")
print("=" * 60)

# TODO 3.1: Update metadata for doc_ml
# Hint: collection.update(ids=[...], metadatas=[...])
print("\n[Task 3.1] Update 'doc_ml' difficulty to 'advanced':")
# Your code here:
collection.update(ids=["doc_ml"], metadatas=[{"difficulty": "advanced"}])
Verify: print(collection.get(ids=["doc_ml"]))


# TODO 3.2: Update document content for doc_api
# Hint: This triggers re-embedding!
print("\n[Task 3.2] Update 'doc_api' content:")
new_api_text = "REST APIs use HTTP methods like GET, POST, PUT, and DELETE to perform CRUD operations on resources."
# Your code here:
collection.update(ids=["doc_api"], documents=[new_api_text])
print(collection.get(ids=["doc_api"]))

# TODO 3.3: Use upsert for doc_python (update) and doc_cloud (insert)
# Hint: collection.upsert() works for both
print("\n[Task 3.3] Upsert operations:")
# Your code here:
collection.upsert(ids=["doc_python"], documents=["Python is a versatile programming language used for web development, data science, and automation."], metadatas=[{"difficulty": "beginner"}])
collection.upsert(ids=["doc_cloud"], documents=["Cloud computing platforms offer scalable storage and compute resources."], metadatas=[{"difficulty": "beginner"}])

print(collection.get(ids=["doc_python"]))
print(collection.get(ids=["doc_cloud"]))
# Out:
# ============================================================
# Part 3: UPDATE Operations
# ============================================================
#
# [Task 3.1] Update 'doc_ml' difficulty to 'advanced':
# {'ids': ['doc_ml'], 'embeddings': None, 'documents': ['Machine learning models require large datasets for training and validation.'], 'uris': None, 'included': ['metadatas', 'documents'], 'data': None, 'metadatas': [{'difficulty': 'advanced', 'category': 'ai', 'author': 'bob'}]}
#
# [Task 3.2] Update 'doc_api' content:
# {'ids': ['doc_api'], 'embeddings': None, 'documents': ['REST APIs use HTTP methods like GET, POST, PUT, and DELETE to perform CRUD operations on resources.'], 'uris': None, 'included': ['metadatas', 'documents'], 'data': None, 'metadatas': [{'category': 'programming', 'author': 'bob', 'difficulty': 'beginner'}]}
#
# [Task 3.3] Upsert operations:
# {'ids': ['doc_python'], 'embeddings': None, 'documents': ['Python is a versatile programming language used for web development, data science, and automation.'], 'uris': None, 'included': ['metadatas', 'documents'], 'data': None, 'metadatas': [{'category': 'programming', 'author': 'alice', 'difficulty': 'beginner'}]}
# {'ids': ['doc_cloud'], 'embeddings': None, 'documents': ['Cloud computing platforms offer scalable storage and compute resources.'], 'uris': None, 'included': ['metadatas', 'documents'], 'data': None, 'metadatas': [{'difficulty': 'beginner'}]}

# %%
# ============================================================================
# PART 4: DELETE Operations
# ============================================================================

print("\n" + "=" * 60)
print("Part 4: DELETE Operations")
print("=" * 60)

# TODO 4.1: Delete by ID
# Hint: collection.delete(ids=[...])
print("\n[Task 4.1] Delete 'doc_docker':")
print(f"Count before: {collection.count()}")
collection.delete(ids=["doc_docker"])
print(f"Count after: {collection.count()}")


# TODO 4.2: Delete by filter
# Hint: collection.delete(where={...})
print("\n[Task 4.2] Delete all documents by 'carol':")
print(f"Count before: {collection.count()}")
collection.delete(where={"author": "carol"})
print(f"Count after: {collection.count()}")


# TODO 4.3: Verify deletions
print("\n[Task 4.3] Verification:")
# Try to get deleted documents - should return empty
deleted_docker = collection.get(ids=["doc_docker"])
deleted_carol = collection.get(where={"author": "carol"})
print(f"doc_docker exists: {len(deleted_docker['ids']) > 0}")
print(f"carol's documents exist: {len(deleted_carol['ids']) > 0}")
print(f"\nFinal collection count: {collection.count()}")
# Out:
# ============================================================
# Part 4: DELETE Operations
# ============================================================
#
# [Task 4.1] Delete 'doc_docker':
# Count before: 6
# Count after: 5
#
# [Task 4.2] Delete all documents by 'carol':
# Count before: 5
# Count after: 4
#
# [Task 4.3] Verification:
# doc_docker exists: False
# carol's documents exist: False
#
# Final collection count: 4

# %%
# ============================================================================
# PART 5: Collection Management
# ============================================================================

print("\n" + "=" * 60)
print("Part 5: Collection Management")
print("=" * 60)

# TODO 5.1: List all collections
# Hint: client.list_collections()
print("\n[Task 5.1] List collections:")
# Your code here:
print(client.list_collections())


# TODO 5.2: Create a second collection
print("\n[Task 5.2] Create 'archived_docs' collection:")
# Your code here:
collection = client.create_collection("archived_docs")
print(client.list_collections())

# TODO 5.3: Delete a collection
# Hint: client.delete_collection(name=...)
print("\n[Task 5.3] Delete 'archived_docs' collection:")
# Your code here:
client.delete_collection("archived_docs")
print(client.list_collections())

print("\n" + "=" * 60)
print("Exercise Complete!")
print("=" * 60)
# Out:
# ============================================================
# Part 5: Collection Management
# ============================================================
#
# [Task 5.1] List collections:
# [Collection(name=knowledge_base)]
#
# [Task 5.2] Create 'archived_docs' collection:
# [Collection(name=archived_docs), Collection(name=knowledge_base)]
#
# [Task 5.3] Delete 'archived_docs' collection:
# [Collection(name=knowledge_base)]
#
# ============================================================
# Exercise Complete!
# ============================================================

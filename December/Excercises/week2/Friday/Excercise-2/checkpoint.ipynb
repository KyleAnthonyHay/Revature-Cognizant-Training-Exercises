# %%
"""
Exercise 02: Checkpoint Strategy - Starter Code

Implement optimal checkpointing for long training runs.

Prerequisites:
- Reading: 02-model-checkpoints.md
- Demo: demo_02_checkpoint_callback.py (KEY REFERENCE)
"""

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import os
import shutil

# Setup
CKPT_DIR = 'checkpoints'
if os.path.exists(CKPT_DIR):
    shutil.rmtree(CKPT_DIR)
os.makedirs(CKPT_DIR)

# %%
# ============================================================================
# SETUP (PROVIDED)
# ============================================================================

def load_data():
    """Load MNIST subset"""
    (x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
    x_train = x_train[:10000].reshape(-1, 784).astype('float32') / 255.0
    x_test = x_test.reshape(-1, 784).astype('float32') / 255.0
    return (x_train, y_train[:10000]), (x_test, y_test)

def create_model():
    """Create simple model"""
    model = keras.Sequential([
        layers.Dense(128, activation='relu', input_shape=(784,)),
        layers.Dense(64, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# ============================================================================
# TASK 2.1: Basic Checkpointing
# ============================================================================

def basic_checkpointing():
    """
    Save checkpoint after every epoch.
    
    ModelCheckpoint PARAMETERS:
    - filepath: where to save (use {epoch:02d} for epoch number)
    - save_weights_only: True for smaller files
    - save_freq: 'epoch' or integer (batches)
    - verbose: 1 to print save messages
    
    FILEPATH PATTERN:
    'checkpoints/ckpt_epoch-{epoch:02d}.keras'
    -> Creates: ckpt_epoch-01.keras, ckpt_epoch-02.keras, etc.
    """
    print("Task 2.1: Basic Checkpointing")
    
    (x_train, y_train), (x_test, y_test) = load_data()
    model = create_model()
    
    checkpoint_cb = keras.callbacks.ModelCheckpoint(
        filepath='checkpoints/ckpt_epoch-{epoch:02d}.weights.h5',
        save_weights_only=True,
        save_freq='epoch',
        verbose=1
    )
    
    model.fit(
        x_train, y_train,
        epochs=5,
        validation_data=(x_test, y_test),
        callbacks=[checkpoint_cb]
    )
    
    print(f"\nCheckpoints saved: {os.listdir(CKPT_DIR)}")

# %%
# ============================================================================
# TASK 2.2: Save Best Model Only
# ============================================================================

def save_best_only():
    """
    Only save when validation loss improves.
    
    KEY PARAMETERS:
    - monitor='val_loss': Watch validation loss
    - mode='min': Lower is better
    - save_best_only=True: Only save improvements
    
    BENEFIT: Saves disk space, keeps only best model
    """
    print("Task 2.2: Save Best Only")
    
    (x_train, y_train), (x_test, y_test) = load_data()
    model = create_model()
    
    checkpoint_cb = keras.callbacks.ModelCheckpoint(
        filepath='checkpoints/best_model.keras',
        monitor='val_loss',
        mode='min',
        save_best_only=True,
        verbose=1
    )
    
    model.fit(
        x_train, y_train,
        epochs=10,
        validation_data=(x_test, y_test),
        callbacks=[checkpoint_cb]
    )
    
    print(f"\nCheckpoints saved: {os.listdir(CKPT_DIR)}")

# %%
# ============================================================================
# TASK 2.3: Resume Training from Checkpoint
# ============================================================================

def resume_training():
    """
    Simulate crash recovery: train 5 epochs, "crash", resume.
    
    SCENARIO:
    1. Train for 5 epochs, save checkpoint
    2. Clear model (simulate crash)
    3. Load checkpoint
    4. Continue training for 5 more epochs
    
    KEY: After loading, model should continue improving!
    
    HINT: After keras.models.load_model(), you may need to recompile
    if optimizer state issues occur (Keras 3 quirk).
    """
    print("Task 2.3: Resume Training")
    
    (x_train, y_train), (x_test, y_test) = load_data()
    
    # Phase 1: Train for 5 epochs
    print("\n--- Phase 1: Initial Training (5 epochs) ---")
    model = create_model()
    checkpoint_path = 'checkpoints/resume_model.keras'
    
    checkpoint_cb = keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_path,
        save_best_only=False,
        verbose=1
    )
    
    history1 = model.fit(
        x_train, y_train,
        epochs=5,
        validation_data=(x_test, y_test),
        callbacks=[checkpoint_cb]
    )
    
    final_loss_phase1 = history1.history['val_loss'][-1]
    print(f"\nPhase 1 final val_loss: {final_loss_phase1:.4f}")
    
    # Phase 2: Simulate crash
    print("\n--- Simulating Crash (deleting model) ---")
    del model
    
    # Phase 3: Load checkpoint and resume
    print("\n--- Phase 2: Resuming Training (5 more epochs) ---")
    model = keras.models.load_model(checkpoint_path)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    history2 = model.fit(
        x_train, y_train,
        epochs=5,
        validation_data=(x_test, y_test),
        callbacks=[checkpoint_cb]
    )
    
    final_loss_phase2 = history2.history['val_loss'][-1]
    print(f"\nPhase 2 final val_loss: {final_loss_phase2:.4f}")
    print(f"Improvement: {final_loss_phase1 - final_loss_phase2:.4f}")

# %%
# ============================================================================
# TASK 2.4: Cleanup Old Checkpoints
# ============================================================================

class KeepNCheckpoints(keras.callbacks.Callback):
    """Custom callback to keep only the N most recent checkpoints."""
    
    def __init__(self, checkpoint_dir, keep_n=3, pattern='smart_ckpt_epoch-'):
        super().__init__()
        self.checkpoint_dir = checkpoint_dir
        self.keep_n = keep_n
        self.pattern = pattern
    
    def on_epoch_end(self, epoch, logs=None):
        checkpoints = sorted([
            f for f in os.listdir(self.checkpoint_dir) 
            if f.startswith(self.pattern)
        ])
        
        while len(checkpoints) > self.keep_n:
            old_ckpt = checkpoints.pop(0)
            os.remove(os.path.join(self.checkpoint_dir, old_ckpt))
            print(f"  Deleted old checkpoint: {old_ckpt}")

def smart_checkpointing():
    """
    Keep only the N most recent checkpoints to save disk space.
    
    APPROACH:
    1. Use custom callback or post-training cleanup
    2. After each epoch, delete checkpoints older than last N
    
    ALTERNATIVE: Use keras.callbacks.BackupAndRestore for automatic resume
    """
    print("Task 2.4: Smart Checkpointing")
    
    (x_train, y_train), (x_test, y_test) = load_data()
    model = create_model()
    
    checkpoint_cb = keras.callbacks.ModelCheckpoint(
        filepath='checkpoints/smart_ckpt_epoch-{epoch:02d}.keras',
        verbose=1
    )
    
    cleanup_cb = KeepNCheckpoints(CKPT_DIR, keep_n=3)
    
    model.fit(
        x_train, y_train,
        epochs=8,
        validation_data=(x_test, y_test),
        callbacks=[checkpoint_cb, cleanup_cb]
    )
    
    print(f"\nFinal checkpoints (only last 3): {sorted(os.listdir(CKPT_DIR))}")

# %%
# ============================================================================
# MAIN
# ============================================================================

if __name__ == "__main__":
    print("=" * 60)
    print("Exercise 02: Checkpoint Strategy")
    print("=" * 60)
    
    # Uncomment as you complete:
    basic_checkpointing()
    save_best_only()
    resume_training()
    smart_checkpointing()
# Out:
# ============================================================
# Exercise 02: Checkpoint Strategy
# ============================================================
# Task 2.1: Basic Checkpointing
# Epoch 1/5
# 300/313 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - accuracy: 0.7369 - loss: 0.8928
# Epoch 1: saving model to checkpoints/ckpt_epoch-01.weights.h5
#
# Epoch 1: finished saving model to checkpoints/ckpt_epoch-01.weights.h5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8557 - loss: 0.5058 - val_accuracy: 0.9241 - val_loss: 0.2691
# Epoch 2/5
# 290/313 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.9376 - loss: 0.2158
# Epoch 2: saving model to checkpoints/ckpt_epoch-02.weights.h5
#
# Epoch 2: finished saving model to checkpoints/ckpt_epoch-02.weights.h5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9399 - loss: 0.2095 - val_accuracy: 0.9349 - val_loss: 0.2188
# Epoch 3/5
# 254/313 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.9573 - loss: 0.1520
# Epoch 3: saving model to checkpoints/ckpt_epoch-03.weights.h5
#
# Epoch 3: finished saving model to checkpoints/ckpt_epoch-03.weights.h5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9588 - loss: 0.1421 - val_accuracy: 0.9425 - val_loss: 0.1886
# Epoch 4/5
# 290/313 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.9705 - loss: 0.0970
# Epoch 4: saving model to checkpoints/ckpt_epoch-04.weights.h5
#
# Epoch 4: finished saving model to checkpoints/ckpt_epoch-04.weights.h5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9683 - loss: 0.1041 - val_accuracy: 0.9461 - val_loss: 0.1744
# Epoch 5/5
# 300/313 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - accuracy: 0.9815 - loss: 0.0745
# Epoch 5: saving model to checkpoints/ckpt_epoch-05.weights.h5
#
# Epoch 5: finished saving model to checkpoints/ckpt_epoch-05.weights.h5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9811 - loss: 0.0690 - val_accuracy: 0.9490 - val_loss: 0.1740
#
# Checkpoints saved: ['ckpt_epoch-04.weights.h5', 'smart_ckpt_epoch-07.keras', 'resume_model.keras', 'ckpt_epoch-01.weights.h5', 'smart_ckpt_epoch-06.keras', 'ckpt_epoch-03.weights.h5', 'smart_ckpt_epoch-08.keras', 'ckpt_epoch-05.weights.h5', 'ckpt_epoch-02.weights.h5']
# Task 2.2: Save Best Only
# Epoch 1/10
# 282/313 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.7216 - loss: 0.9674
# Epoch 1: val_loss improved from None to 0.27695, saving model to checkpoints/best_model.keras
#
# Epoch 1: finished saving model to checkpoints/best_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8543 - loss: 0.5224 - val_accuracy: 0.9168 - val_loss: 0.2769
# Epoch 2/10
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - accuracy: 0.9306 - loss: 0.2308
# Epoch 2: val_loss improved from 0.27695 to 0.22129, saving model to checkpoints/best_model.keras
#
# Epoch 2: finished saving model to checkpoints/best_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9364 - loss: 0.2133 - val_accuracy: 0.9362 - val_loss: 0.2213
# Epoch 3/10
# 245/313 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - accuracy: 0.9571 - loss: 0.1341
# Epoch 3: val_loss improved from 0.22129 to 0.18674, saving model to checkpoints/best_model.keras
#
# Epoch 3: finished saving model to checkpoints/best_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9548 - loss: 0.1454 - val_accuracy: 0.9421 - val_loss: 0.1867
# Epoch 4/10
# 307/313 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - accuracy: 0.9712 - loss: 0.1008
# Epoch 4: val_loss improved from 0.18674 to 0.17218, saving model to checkpoints/best_model.keras
#
# Epoch 4: finished saving model to checkpoints/best_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9684 - loss: 0.1038 - val_accuracy: 0.9477 - val_loss: 0.1722
# Epoch 5/10
# 303/313 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - accuracy: 0.9818 - loss: 0.0706
# Epoch 5: val_loss improved from 0.17218 to 0.16293, saving model to checkpoints/best_model.keras
#
# Epoch 5: finished saving model to checkpoints/best_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9805 - loss: 0.0701 - val_accuracy: 0.9506 - val_loss: 0.1629
# Epoch 6/10
# 300/313 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step - accuracy: 0.9871 - loss: 0.0475
# Epoch 6: val_loss did not improve from 0.16293
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9858 - loss: 0.0506 - val_accuracy: 0.9471 - val_loss: 0.1752
# Epoch 7/10
# 239/313 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - accuracy: 0.9921 - loss: 0.0322
# Epoch 7: val_loss improved from 0.16293 to 0.16046, saving model to checkpoints/best_model.keras
#
# Epoch 7: finished saving model to checkpoints/best_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9903 - loss: 0.0374 - val_accuracy: 0.9520 - val_loss: 0.1605
# Epoch 8/10
# 254/313 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - accuracy: 0.9950 - loss: 0.0236
# Epoch 8: val_loss did not improve from 0.16046
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - accuracy: 0.9924 - loss: 0.0293 - val_accuracy: 0.9407 - val_loss: 0.2115
# Epoch 9/10
# 258/313 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - accuracy: 0.9938 - loss: 0.0243
# Epoch 9: val_loss did not improve from 0.16046
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - accuracy: 0.9942 - loss: 0.0223 - val_accuracy: 0.9463 - val_loss: 0.1954
# Epoch 10/10
# 239/313 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - accuracy: 0.9963 - loss: 0.0168
# Epoch 10: val_loss did not improve from 0.16046
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - accuracy: 0.9966 - loss: 0.0153 - val_accuracy: 0.9510 - val_loss: 0.1908
#
# Checkpoints saved: ['ckpt_epoch-04.weights.h5', 'smart_ckpt_epoch-07.keras', 'resume_model.keras', 'ckpt_epoch-01.weights.h5', 'best_model.keras', 'smart_ckpt_epoch-06.keras', 'ckpt_epoch-03.weights.h5', 'smart_ckpt_epoch-08.keras', 'ckpt_epoch-05.weights.h5', 'ckpt_epoch-02.weights.h5']
# Task 2.3: Resume Training
#
# --- Phase 1: Initial Training (5 epochs) ---
# Epoch 1/5
# 243/313 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - accuracy: 0.7075 - loss: 0.9993
# Epoch 1: saving model to checkpoints/resume_model.keras
#
# Epoch 1: finished saving model to checkpoints/resume_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8523 - loss: 0.5226 - val_accuracy: 0.9164 - val_loss: 0.2870
# Epoch 2/5
# 254/313 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.9347 - loss: 0.2327
# Epoch 2: saving model to checkpoints/resume_model.keras
#
# Epoch 2: finished saving model to checkpoints/resume_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - accuracy: 0.9370 - loss: 0.2164 - val_accuracy: 0.9389 - val_loss: 0.2149
# Epoch 3/5
# 245/313 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - accuracy: 0.9535 - loss: 0.1595
# Epoch 3: saving model to checkpoints/resume_model.keras
#
# Epoch 3: finished saving model to checkpoints/resume_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - accuracy: 0.9557 - loss: 0.1490 - val_accuracy: 0.9438 - val_loss: 0.1920
# Epoch 4/5
# 252/313 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - accuracy: 0.9738 - loss: 0.0959
# Epoch 4: saving model to checkpoints/resume_model.keras
#
# Epoch 4: finished saving model to checkpoints/resume_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - accuracy: 0.9698 - loss: 0.1049 - val_accuracy: 0.9469 - val_loss: 0.1830
# Epoch 5/5
# 297/313 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - accuracy: 0.9796 - loss: 0.0776
# Epoch 5: saving model to checkpoints/resume_model.keras
#
# Epoch 5: finished saving model to checkpoints/resume_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9792 - loss: 0.0766 - val_accuracy: 0.9486 - val_loss: 0.1737
#
# Phase 1 final val_loss: 0.1737
#
# --- Simulating Crash (deleting model) ---
#
# --- Phase 2: Resuming Training (5 more epochs) ---
# Epoch 1/5
# 246/313 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 0.9819 - loss: 0.0641
# Epoch 1: saving model to checkpoints/resume_model.keras
#
# Epoch 1: finished saving model to checkpoints/resume_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9822 - loss: 0.0650 - val_accuracy: 0.9469 - val_loss: 0.1804
# Epoch 2/5
# 237/313 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - accuracy: 0.9871 - loss: 0.0411
# Epoch 2: saving model to checkpoints/resume_model.keras
#
# Epoch 2: finished saving model to checkpoints/resume_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9861 - loss: 0.0465 - val_accuracy: 0.9477 - val_loss: 0.1786
# Epoch 3/5
# 297/313 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - accuracy: 0.9896 - loss: 0.0349
# Epoch 3: saving model to checkpoints/resume_model.keras
#
# Epoch 3: finished saving model to checkpoints/resume_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9901 - loss: 0.0326 - val_accuracy: 0.9554 - val_loss: 0.1645
# Epoch 4/5
# 260/313 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - accuracy: 0.9960 - loss: 0.0164
# Epoch 4: saving model to checkpoints/resume_model.keras
#
# Epoch 4: finished saving model to checkpoints/resume_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.9950 - loss: 0.0189 - val_accuracy: 0.9506 - val_loss: 0.1920
# Epoch 5/5
# 251/313 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.9954 - loss: 0.0195
# Epoch 5: saving model to checkpoints/resume_model.keras
#
# Epoch 5: finished saving model to checkpoints/resume_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9957 - loss: 0.0173 - val_accuracy: 0.9533 - val_loss: 0.1812
#
# Phase 2 final val_loss: 0.1812
# Improvement: -0.0075
# Task 2.4: Smart Checkpointing
# Epoch 1/8
# 246/313 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 0.6986 - loss: 1.0398
# Epoch 1: saving model to checkpoints/smart_ckpt_epoch-01.keras
#
# Epoch 1: finished saving model to checkpoints/smart_ckpt_epoch-01.keras
#   Deleted old checkpoint: smart_ckpt_epoch-01.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8494 - loss: 0.5337 - val_accuracy: 0.9177 - val_loss: 0.2814
# Epoch 2/8
# 246/313 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step - accuracy: 0.9311 - loss: 0.2325
# Epoch 2: saving model to checkpoints/smart_ckpt_epoch-02.keras
#
# Epoch 2: finished saving model to checkpoints/smart_ckpt_epoch-02.keras
#   Deleted old checkpoint: smart_ckpt_epoch-02.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9358 - loss: 0.2200 - val_accuracy: 0.9352 - val_loss: 0.2163
# Epoch 3/8
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - accuracy: 0.9587 - loss: 0.1427
# Epoch 3: saving model to checkpoints/smart_ckpt_epoch-03.keras
#
# Epoch 3: finished saving model to checkpoints/smart_ckpt_epoch-03.keras
#   Deleted old checkpoint: smart_ckpt_epoch-03.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9558 - loss: 0.1506 - val_accuracy: 0.9332 - val_loss: 0.2158
# Epoch 4/8
# 252/313 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.9646 - loss: 0.1122
# Epoch 4: saving model to checkpoints/smart_ckpt_epoch-04.keras
#
# Epoch 4: finished saving model to checkpoints/smart_ckpt_epoch-04.keras
#   Deleted old checkpoint: smart_ckpt_epoch-04.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - accuracy: 0.9688 - loss: 0.1068 - val_accuracy: 0.9422 - val_loss: 0.1836
# Epoch 5/8
# 252/313 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - accuracy: 0.9791 - loss: 0.0716
# Epoch 5: saving model to checkpoints/smart_ckpt_epoch-05.keras
#
# Epoch 5: finished saving model to checkpoints/smart_ckpt_epoch-05.keras
#   Deleted old checkpoint: smart_ckpt_epoch-05.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - accuracy: 0.9766 - loss: 0.0780 - val_accuracy: 0.9457 - val_loss: 0.1707
# Epoch 6/8
# 238/313 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - accuracy: 0.9828 - loss: 0.0644
# Epoch 6: saving model to checkpoints/smart_ckpt_epoch-06.keras
#
# Epoch 6: finished saving model to checkpoints/smart_ckpt_epoch-06.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9826 - loss: 0.0635 - val_accuracy: 0.9483 - val_loss: 0.1759
# Epoch 7/8
# 255/313 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - accuracy: 0.9885 - loss: 0.0434
# Epoch 7: saving model to checkpoints/smart_ckpt_epoch-07.keras
#
# Epoch 7: finished saving model to checkpoints/smart_ckpt_epoch-07.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - accuracy: 0.9868 - loss: 0.0484 - val_accuracy: 0.9532 - val_loss: 0.1525
# Epoch 8/8
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - accuracy: 0.9915 - loss: 0.0332
# Epoch 8: saving model to checkpoints/smart_ckpt_epoch-08.keras
#
# Epoch 8: finished saving model to checkpoints/smart_ckpt_epoch-08.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9894 - loss: 0.0367 - val_accuracy: 0.9459 - val_loss: 0.1855
#
# Final checkpoints (only last 3): ['best_model.keras', 'ckpt_epoch-01.weights.h5', 'ckpt_epoch-02.weights.h5', 'ckpt_epoch-03.weights.h5', 'ckpt_epoch-04.weights.h5', 'ckpt_epoch-05.weights.h5', 'resume_model.keras', 'smart_ckpt_epoch-06.keras', 'smart_ckpt_epoch-07.keras', 'smart_ckpt_epoch-08.keras']

# %% [markdown]
# Sequence Padding
#
# The Variable Length Sequence Problem

# %%
"Hi"                                     # 1 word
"I love NLP"                             # 3 words
"The quick brown fox jumps over lazy"    # 7 words

# %% [markdown]
# ## Pre-Padding vs Post-Padding
#
# ### Pre
# Sequence: [0, 0, 0, I, love, Spencer's, Teaching]
# ### Post
# Sequence: [I, love, Spencer's, Teaching, 0, 0, 0]
